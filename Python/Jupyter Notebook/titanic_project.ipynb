# %%
import pandas as pd
data = pd.read_csv(r"D:\Documents\Coding\Python\Files\titanic.csv")

# Set Pandas options to display more rows and columns
pd.set_option('display.max_rows', None)  # Show all rows
pd.set_option('display.max_columns', None)  # Show all columns

data
# Out:
#      survived  pclass     sex    age  sibsp  parch      fare embarked   class  \
# 0           0       3    male  22.00      1      0    7.2500        S   Third
# 1           1       1  female  38.00      1      0   71.2833        C   First
# 2           1       3  female  26.00      0      0    7.9250        S   Third
# 3           1       1  female  35.00      1      0   53.1000        S   First
# 4           0       3    male  35.00      0      0    8.0500        S   Third
# 5           0       3    male    NaN      0      0    8.4583        Q   Third
# 6           0       1    male  54.00      0      0   51.8625        S   First
# 7           0       3    male   2.00      3      1   21.0750        S   Third
# 8           1       3  female  27.00      0      2   11.1333        S   Third
# 9           1       2  female  14.00      1      0   30.0708        C  Second
# 10          1       3  female   4.00      1      1   16.7000        S   Third
# ...

# %%
data.head(10)  # Shows the first 10 rows
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# ...

# %%
data.tail(10)  # Shows the last 0 rows
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 881         0       3    male  33.0      0      0   7.8958        S   Third
# 882         0       3  female  22.0      0      0  10.5167        S   Third
# 883         0       2    male  28.0      0      0  10.5000        S  Second
# 884         0       3    male  25.0      0      0   7.0500        S   Third
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 881    man        True  NaN  Southampton    no   True
# ...

# %%
data[["age", "sex", "adult_male"]].head(10) # Shows only first 10 rows of given data set
# Out:
#     age     sex  adult_male
# 0  22.0    male        True
# 1  38.0  female       False
# 2  26.0  female       False
# 3  35.0  female       False
# 4  35.0    male        True
# 5   NaN    male        True
# 6  54.0    male        True
# 7   2.0    male       False
# 8  27.0  female       False
# 9  14.0  female       False

# %%
subset = data.loc[0:9, ["age", "sex", "adult_male"]]  # First 10 rows and specific columns
subset
# Out:
#     age     sex  adult_male
# 0  22.0    male        True
# 1  38.0  female       False
# 2  26.0  female       False
# 3  35.0  female       False
# 4  35.0    male        True
# 5   NaN    male        True
# 6  54.0    male        True
# 7   2.0    male       False
# 8  27.0  female       False
# 9  14.0  female       False

# %%
print(data.shape)  # (number_of_rows, number_of_columns)
# Out:
# (891, 15)

# %%
print(data.columns)  # List of column names
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
print(data.describe())
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
print(data["age"].describe())
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: age, dtype: float64

# %%
print("Mean:", data["age"].mean())
print("Median:", data["age"].median())
print("Mode:", data["age"].mode()[0])
print("Standard Deviation:", data["age"].std())
# Out:
# Mean: 29.69911764705882
# Median: 28.0
# Mode: 24.0
# Standard Deviation: 14.526497332334042

# %%
filtered_data = data[data["age"] > 30]  # Rows where age > 30
filtered_data.head(10)
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 11         1       1  female  58.0      0      0  26.5500        S   First
# 13         0       3    male  39.0      1      5  31.2750        S   Third
# 15         1       2  female  55.0      0      0  16.0000        S  Second
# 18         0       3  female  31.0      1      0  18.0000        S   Third
# 20         0       2    male  35.0      0      0  26.0000        S  Second
# 21         1       2    male  34.0      0      0  13.0000        S  Second
#
#       who  adult_male deck  embark_town alive  alone
# 1   woman       False    C    Cherbourg   yes  False
# ...

# %%
sample_data = data.sample(10)  # Random sample of 10 rows
sample_data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 369         1       1  female  24.0      0      0  69.3000        C  First
# 650         0       3    male   NaN      0      0   7.8958        S  Third
# 676         0       3    male  24.5      0      0   8.0500        S  Third
# 486         1       1  female  35.0      1      0  90.0000        S  First
# 735         0       3    male  28.5      0      0  16.1000        S  Third
# 59          0       3    male  11.0      5      2  46.9000        S  Third
# 11          1       1  female  58.0      0      0  26.5500        S  First
# 573         1       3  female   NaN      0      0   7.7500        Q  Third
# 645         1       1    male  48.0      1      0  76.7292        C  First
# 579         1       3    male  32.0      0      0   7.9250        S  Third
#
#        who  adult_male deck  embark_town alive  alone
# 369  woman       False    B    Cherbourg   yes   True
# ...

# %%
print(data.isnull().sum())  # Count of missing values per column
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
cleaned_data = data.dropna() #data.dropna() is used to handle missing values in a DataFrame by removing rows with any missing values.
cleaned_data
# Out:
#      survived  pclass     sex    age  sibsp  parch      fare embarked   class  \
# 1           1       1  female  38.00      1      0   71.2833        C   First
# 3           1       1  female  35.00      1      0   53.1000        S   First
# 6           0       1    male  54.00      0      0   51.8625        S   First
# 10          1       3  female   4.00      1      1   16.7000        S   Third
# 11          1       1  female  58.00      0      0   26.5500        S   First
# 21          1       2    male  34.00      0      0   13.0000        S  Second
# 23          1       1    male  28.00      0      0   35.5000        S   First
# 27          0       1    male  19.00      3      2  263.0000        S   First
# 52          1       1  female  49.00      1      0   76.7292        C   First
# 54          0       1    male  65.00      0      1   61.9792        C   First
# 62          0       1    male  45.00      1      0   83.4750        S   First
# ...

# %%
print(cleaned_data.shape)
# Out:
# (182, 15)

# %%
data["sex"].value_counts()  # Count of unique values in the 'sex' column
# Out:
# sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
sorted_data = data.sort_values(by="age", ascending=False)  # Sort by age in descending order
sorted_data.head(10)
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked   class  \
# 630         1       1  male  80.0      0      0  30.0000        S   First
# 851         0       3  male  74.0      0      0   7.7750        S   Third
# 493         0       1  male  71.0      0      0  49.5042        C   First
# 96          0       1  male  71.0      0      0  34.6542        C   First
# 116         0       3  male  70.5      0      0   7.7500        Q   Third
# 745         0       1  male  70.0      1      1  71.0000        S   First
# 672         0       2  male  70.0      0      0  10.5000        S  Second
# 33          0       2  male  66.0      0      0  10.5000        S  Second
# 456         0       1  male  65.0      0      0  26.5500        S   First
# 54          0       1  male  65.0      0      1  61.9792        C   First
#
#      who  adult_male deck  embark_town alive  alone
# 630  man        True    A  Southampton   yes   True
# ...

# %%
#data.to_csv('path/to/save/cleaned_data.csv', index=False)

# %%
import matplotlib.pyplot as plt

data["age"].hist()
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()

# %%
data.plot(kind='scatter', x='age', y='fare')
plt.title("Age vs Fare")
plt.xlabel("Age")
plt.ylabel("Fare")
plt.show()

# %%
# data["age_squared"] = data["age"].apply(lambda x: x**2)  # Create a new column with age squared
# data.head(10)

# %%
# data = data.drop(columns=['age_squared']) # To delete any column.. In this case age_squared

# data

# %%
pivot_table = data.pivot_table(values="fare", index="pclass", aggfunc="mean")  # Average fare by pclass
pivot_table
# Out:
#              fare
# pclass
# 1       84.154687
# 2       20.662183
# 3       13.675550
